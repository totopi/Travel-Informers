# %%
import pandas as pd
import datetime as dt

# %%
# Import the Weather CSV as a Dataframe
max_temps = pd.read_csv("data/weather_data/daily_max_temps.csv")
# Convert the date column to datetime objects
max_temps.datetime = pd.to_datetime(max_temps.datetime)
# Add a column for the Year, Month, and Day of each row
max_temps['year'] = max_temps['datetime'].dt.year
max_temps['month'] = max_temps['datetime'].dt.month
max_temps['day'] = max_temps['datetime'].dt.day

max_temps.head()
# Out:
#     datetime  Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# 0 2012-10-01         53        48             61       48           66
# 1 2012-10-02         64        81             89       73           94
# 2 2012-10-03         65        81             88       72           91
# 3 2012-10-04         63        68             85       62           84
# 4 2012-10-05         64        71             71       63           77
#
#    San Diego  Las Vegas  Phoenix  Albuquerque ...   Miami  Pittsburgh  \
# 0         65         68       75           55 ...      80          47
# 1         88         96      102           77 ...      82          64
# 2         91         98      101           78 ...      85          73
# 3         84         98      101           83 ...      88          73
# 4         77         96       98           81 ...      88          73
#
#    Toronto  Philadelphia  New York  Montreal  Boston  year  month  day
# ...

# %%
# Import the cleaned Crime Data CSV
crime_data = pd.read_csv("data/clean_crime_data.csv")
crime_cols = ['report_year', 'agency_jurisdiction', 'crimes_percapita']
crime_data = crime_data[crime_cols]
crime_data.head()
# Out:
#    report_year agency_jurisdiction  crimes_percapita
# 0         2012     Albuquerque, NM            749.71
# 1         2012         Atlanta, GA           1379.05
# 2         2012          Boston, MA            835.01
# 3         2012       Charlotte, NC            647.86
# 4         2012         Chicago, IL           1019.80

# %%
max_temps.groupby("year").mean()
# Out:
#       Vancouver   Portland  San Francisco    Seattle  Los Angeles  San Diego  \
# year
# 2012  48.913043  54.130435      64.510870  51.804348    70.673913  69.913043
# 2013  56.989041  62.284932      68.427397  59.753425    74.972603  72.027397
# 2014  58.515068  63.076712      68.073973  60.794521    74.989041  74.547945
# 2015  58.553425  64.567123      68.534247  61.772603    75.934247  74.161644
# 2016  59.183060  64.680328      70.972678  61.606557    77.218579  74.210383
# 2017  60.142857  66.694352      73.099668  63.362126    77.073090  73.671096
#
#       Las Vegas    Phoenix  Albuquerque     Denver    ...      Charlotte  \
# year                                                  ...
# 2012  69.456522  78.206522    58.086957  56.402174    ...      62.902174
# 2013  79.912329  86.027397    67.284932  62.317808    ...      69.145205
# 2014  79.753425  85.463014    69.076712  61.775342    ...      69.597260
# ...

# %%
crime_data.groupby("report_year").mean()
# Out:
#              crimes_percapita
# report_year
# 2012               891.394286
# 2013               864.963214
# 2014               864.682143
# 2015               890.754444
