# %%
import datetime as dt
import numpy as np
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

import pymysql
pymysql.install_as_MySQLdb()

# %%
engine = create_engine('mysql://nzc05xl12rgoh7ei:v1h64j9hgv2ky4g1@s3lkt7lynu0uthj8.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/x5t20wxo8nmqqxfz')

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
session = Session(engine)

# %%
Base.classes.keys()
# Out:
# ['city_attributes',
#  'daily_2015_avg_wind',
#  'daily_2015_max_wind',
#  'daily_avg_temps',
#  'daily_max_temps',
#  'daily_min_temps']

# %%
Avg_wind = Base.classes.daily_2015_avg_wind
Max_wind = Base.classes.daily_2015_max_wind
Avg_temp = Base.classes.daily_avg_temps
Max_temp = Base.classes.daily_max_temps
Min_temp = Base.classes.daily_min_temps

# %%
qlist = [Avg_temp, Max_temp, Min_temp]

# %%
alist = []
for row in session.query(Min_temp.Vancouver, Max_temp.datetime).filter(Min_temp.datetime.like('2015-05%')).all():
    #print(type(row[1]))
    if (type(row[1]) == str):
        foo = dt.datetime.strptime(row[1], '%Y-%m-%d')
        print(foo)
        alist.append(foo)
    elif (type(row[1] == dt.datetime)):
        print(row[1])
alist
# Out:
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-01 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-02 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-03 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-04 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-05 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-06 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-07 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-08 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-09 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-10 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-11 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-12 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-13 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-14 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-15 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-16 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-17 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-18 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-19 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-20 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-21 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-22 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-23 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-24 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-25 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-26 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-27 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-28 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-29 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-30 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-01-31 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-01 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# <class 'datetime.datetime'>
# 2015-02-02 00:00:00
# ...
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-29 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-30 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-03-31 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-01 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-02 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-03 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-04 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-05 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-06 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-07 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# <class 'datetime.datetime'>
# 2017-04-08 00:00:00
# []

# %%
import datetime as dt

# %%
x.append(row[1] + dt.timedelta(0, 0, 0, 0))

# %%
for i in range(3):
    for row in session.query(qlist[i].Vancouver).all():
        print(row[0])
# Out:
# 32.9600000000
# 35.5800000000
# 36.3800000000
# 37.8800000000
# 40.1700000000
# 44.6700000000
# 42.2900000000
# 42.0400000000
# 41.8800000000
# 41.7500000000
# 43.0800000000
# 43.4200000000
# 42.1200000000
# 42.0800000000
# 41.2500000000
# 45.2900000000
# 43.9600000000
# 45.5400000000
# 45.2900000000
# 43.2500000000
# 41.7500000000
# 42.3800000000
# 44.7500000000
# 47.2100000000
# 47.9600000000
# 46.2500000000
# 46.5400000000
# 45.3300000000
# 44.2900000000
# 44.0000000000
# 43.0800000000
# 43.6200000000
# 43.4200000000
# 43.5000000000
# 44.7900000000
# 45.6200000000
# 49.5400000000
# 48.6700000000
# 48.2100000000
# 47.3800000000
# 47.2900000000
# 46.7500000000
# 47.3800000000
# 48.1200000000
# 47.9200000000
# 46.0800000000
# 46.3300000000
# 42.2100000000
# 46.4600000000
# 45.7500000000
# 44.7500000000
# 44.6700000000
# 44.8300000000
# 44.2900000000
# 44.0800000000
# 43.6200000000
# 43.4200000000
# 42.5800000000
# 45.2900000000
# 40.9200000000
# 44.1200000000
# 42.9600000000
# 38.3300000000
# 41.3300000000
# 44.5000000000
# 45.3300000000
# 45.5000000000
# 45.0000000000
# 44.4200000000
# 48.5400000000
# 49.2500000000
# 49.6700000000
# 50.2100000000
# 46.2500000000
# 44.1700000000
# 43.0800000000
# 44.6200000000
# 46.1700000000
# 47.5400000000
# 47.7500000000
# 43.5800000000
# 44.7500000000
# 44.2100000000
# 44.7900000000
# 50.1700000000
# 51.0400000000
# 49.8300000000
# 46.7900000000
# 49.4600000000
# 48.2900000000
# 45.6700000000
# 42.9200000000
# 43.7100000000
# 41.1200000000
# 41.3300000000
# 44.2900000000
# 44.3300000000
# 45.5800000000
# 46.1200000000
# 46.7500000000
# 43.5000000000
# 41.8300000000
# 41.8300000000
# 43.2900000000
# 42.8300000000
# 43.8300000000
# 48.3300000000
# 50.2100000000
# 51.1200000000
# 53.0400000000
# 52.2500000000
# 48.3800000000
# 47.2500000000
# 44.7900000000
# 45.9600000000
# 49.0400000000
# 49.9600000000
# 53.1700000000
# 49.8300000000
# 49.9600000000
# 50.9200000000
# 51.0000000000
# 52.1700000000
# 52.8300000000
# 49.6700000000
# 50.8800000000
# 53.7100000000
# 56.0800000000
# 57.4600000000
# 57.4200000000
# 56.7100000000
# 56.7100000000
# 56.7500000000
# 54.4600000000
# 58.0800000000
# 57.4600000000
# 57.2900000000
# 59.2100000000
# 61.6700000000
# 61.7900000000
# 63.0400000000
# 62.2100000000
# 60.6700000000
# 59.0400000000
# 56.9200000000
# 56.7100000000
# 60.1700000000
# 62.5400000000
# 64.0800000000
# 61.7100000000
# 59.9600000000
# 64.4200000000
# 57.9600000000
# 56.2900000000
# 56.7100000000
# 59.9200000000
# 62.7500000000
# 64.5800000000
# 68.6200000000
# 67.7900000000
# 65.1200000000
# 63.1700000000
# 60.6200000000
# 57.3800000000
# 60.1200000000
# 65.9600000000
# 66.5800000000
# 63.5400000000
# 61.8300000000
# 57.1200000000
# 59.7100000000
# 61.4200000000
# 62.3300000000
# 60.9200000000
# 63.5400000000
# 65.5000000000
# 72.2100000000
# 73.7500000000
# 76.9600000000
# 73.8300000000
# 72.8300000000
# 72.4200000000
# 75.1200000000
# 74.3300000000
# 73.9600000000
# 75.4200000000
# 72.1700000000
# 68.5400000000
# 68.6700000000
# 70.7500000000
# 68.7900000000
# 65.2900000000
# 63.2100000000
# 66.5800000000
# 66.0800000000
# 65.7100000000
# 66.7500000000
# 66.6200000000
# 71.8800000000
# 75.2500000000
# 72.2900000000
# 66.7100000000
# 63.9600000000
# 65.1700000000
# 63.1200000000
# 62.0800000000
# 61.3300000000
# 61.9200000000
# 65.4600000000
# 67.8300000000
# 71.7900000000
# 72.7500000000
# 71.5800000000
# 72.1700000000
# 69.3800000000
# 67.2500000000
# 62.7100000000
# 61.7100000000
# 64.5000000000
# 65.8300000000
# 66.1200000000
# 65.8800000000
# 68.5000000000
# 73.0000000000
# 71.4200000000
# 65.9200000000
# 63.1200000000
# 64.0000000000
# 65.4600000000
# 69.0800000000
# 71.7500000000
# 66.4200000000
# 64.6200000000
# 64.0000000000
# 66.2500000000
# 64.7900000000
# 62.5800000000
# 63.6700000000
# 67.0800000000
# 66.6200000000
# 64.8300000000
# 60.7100000000
# 59.8800000000
# 59.4600000000
# 56.0000000000
# 54.2100000000
# 54.2500000000
# 56.2900000000
# 56.3800000000
# 56.6700000000
# 61.1200000000
# 62.6700000000
# 63.2500000000
# 65.3800000000
# 64.4600000000
# 63.7100000000
# 56.7900000000
# 54.0800000000
# 55.9200000000
# 56.8800000000
# 57.8300000000
# 59.0400000000
# 62.7900000000
# 54.0400000000
# 51.4600000000
# 53.4600000000
# 56.5000000000
# 55.9600000000
# 53.0400000000
# 50.4200000000
# 52.2900000000
# 55.8800000000
# 55.2500000000
# 55.1700000000
# 54.3800000000
# 55.5800000000
# 56.6700000000
# 53.7100000000
# 54.4200000000
# 57.0000000000
# 58.7100000000
# 60.4200000000
# 63.3800000000
# 56.3800000000
# 54.1700000000
# 54.5800000000
# 51.0000000000
# 54.5000000000
# 55.5800000000
# 56.2900000000
# 54.5000000000
# 54.4200000000
# 53.7100000000
# 50.2900000000
# 51.7500000000
# 47.3300000000
# 44.8800000000
# 49.8300000000
# 52.0000000000
# 50.3800000000
# 49.0000000000
# 50.7900000000
# 51.3800000000
# 51.3800000000
# 48.2900000000
# 45.4200000000
# 42.4600000000
# 41.2900000000
# 46.0800000000
# 42.7100000000
# 48.3300000000
# 45.9200000000
# 42.5000000000
# 40.0400000000
# 45.3300000000
# 42.1700000000
# 46.7100000000
# 45.1700000000
# 41.7900000000
# 37.3800000000
# 43.6200000000
# 40.7500000000
# 38.3800000000
# 33.6700000000
# 32.9600000000
# 33.5400000000
# 37.4600000000
# 39.7900000000
# 33.6700000000
# 33.2900000000
# 32.6200000000
# 30.7500000000
# 29.6700000000
# 27.4200000000
# 38.5400000000
# 41.7100000000
# 47.7500000000
# 43.7900000000
# 44.6200000000
# 45.7100000000
# 45.6200000000
# 46.5400000000
# 45.5000000000
# 43.5400000000
# 42.0400000000
# 37.5800000000
# 42.7100000000
# 40.6200000000
# 36.9600000000
# 36.5800000000
# 33.3300000000
# 36.0800000000
# 38.3800000000
# 43.1700000000
# 39.2100000000
# 36.5800000000
# 36.5800000000
# 36.8300000000
# 35.0000000000
# 32.6200000000
# 35.7500000000
# 35.1700000000
# 34.7900000000
# 30.4600000000
# 27.3800000000
# 27.1200000000
# 26.8800000000
# 27.1200000000
# 31.0400000000
# 31.4600000000
# 36.6700000000
# 36.1200000000
# 37.2100000000
# 35.2500000000
# 34.0400000000
# 32.7900000000
# 36.8800000000
# 44.2900000000
# 37.7100000000
# 32.2500000000
# 38.8800000000
# 42.4600000000
# 45.0400000000
# 44.5800000000
# 39.8800000000
# 44.6700000000
# 46.3800000000
# 41.6200000000
# 40.0800000000
# 38.5400000000
# 44.4600000000
# 49.1200000000
# 52.6200000000
# 41.9200000000
# 38.5400000000
# 36.4600000000
# 38.9200000000
# 38.8300000000
# 39.9200000000
# 39.6700000000
# 45.7500000000
# 44.8800000000
# 36.8300000000
# 42.9600000000
# 44.1700000000
# 45.8800000000
# 46.0400000000
# 49.0000000000
# 46.0800000000
# 43.0800000000
# 46.4600000000
# 47.0800000000
# 43.7100000000
# 44.3300000000
# 44.0800000000
# 43.7100000000
# 38.5000000000
# 43.5400000000
# 40.2900000000
# 45.2100000000
# 44.8800000000
# 45.3800000000
# 46.9200000000
# 48.2900000000
# 45.9200000000
# 45.9200000000
# 47.8300000000
# 49.3800000000
# 49.7900000000
# 50.8300000000
# 51.8800000000
# 45.7900000000
# 44.4200000000
# 45.4200000000
# 49.1700000000
# 46.0800000000
# 47.2100000000
# 44.2100000000
# 43.3300000000
# 43.2900000000
# 43.6700000000
# 42.4600000000
# 46.3800000000
# 48.1200000000
# 50.3800000000
# 50.8300000000
# 48.8800000000
# 48.2900000000
# 46.6200000000
# 45.5000000000
# 45.6200000000
# 47.8800000000
# 45.1700000000
# 46.9200000000
# 50.8300000000
# 52.7500000000
# 54.3800000000
# 53.0800000000
# 51.5000000000
# 53.3800000000
# 48.2900000000
# 52.4600000000
# 54.7100000000
# 56.4600000000
# 54.0400000000
# 51.0400000000
# 52.2100000000
# 51.0000000000
# 47.6700000000
# 49.2100000000
# 49.6700000000
# 50.4200000000
# 52.8800000000
# 58.1200000000
# 60.2100000000
# 60.9200000000
# 58.1200000000
# 55.9200000000
# 56.7100000000
# 53.2900000000
# 50.5800000000
# 50.3800000000
# 52.8300000000
# 54.3800000000
# 55.5400000000
# 53.7500000000
# 57.0000000000
# 62.8800000000
# 66.7500000000
# 57.1700000000
# 55.7500000000
# 61.4200000000
# 63.9200000000
# 59.2900000000
# 54.2500000000
# 57.5400000000
# 61.9200000000
# 59.8300000000
# 64.0400000000
# 66.1200000000
# 58.6700000000
# 56.5400000000
# 58.3300000000
# 60.5800000000
# 54.2500000000
# 55.4600000000
# 58.3800000000
# 57.6700000000
# 58.4200000000
# 59.0400000000
# 59.5400000000
# 57.2900000000
# 53.3300000000
# 52.2900000000
# 55.2100000000
# 57.5400000000
# 61.0800000000
# 64.0000000000
# 60.0000000000
# 62.5000000000
# 67.9600000000
# 72.5800000000
# 72.4200000000
# 67.7100000000
# 64.2100000000
# 58.2100000000
# 57.0400000000
# 55.2500000000
# 57.2900000000
# 58.7500000000
# 52.7900000000
# 51.4600000000
# 54.9600000000
# 58.9600000000
# 59.5800000000
# 55.6700000000
# 60.5000000000
# 62.9200000000
# 61.7900000000
# 59.3800000000
# 58.6200000000
# 60.6200000000
# 63.2900000000
# 68.5800000000
# 67.6200000000
# 65.7500000000
# 63.0800000000
# 62.0400000000
# 64.9200000000
# 65.2500000000
# 62.0800000000
# 60.0400000000
# 59.9600000000
# 61.9200000000
# 61.0800000000
# 61.9200000000
# 61.5800000000
# 62.7100000000
# 62.2500000000
# 64.1200000000
# 62.0400000000
# 61.2500000000
# 62.8800000000
# 64.6200000000
# 62.7500000000
# 64.0000000000
# 64.7900000000
# 65.9200000000
# 68.5000000000
# 64.8800000000
# 65.4200000000
# 68.9200000000
# 68.6200000000
# 68.4600000000
# 71.2900000000
# 71.8300000000
# 68.6700000000
# 64.6200000000
# 64.9600000000
# 62.9200000000
# 61.3800000000
# 65.0800000000
# 66.2100000000
# 62.5800000000
# 61.0800000000
# 62.5000000000
# 62.3300000000
# 34.8300000000
# 38.6200000000
# 40.6700000000
# 41.0400000000
# 36.9200000000
# 33.6200000000
# 32.5400000000
# 30.5400000000
# 31.5000000000
# 31.7500000000
# 29.3800000000
# 28.9600000000
# 25.9600000000
# 31.4600000000
# 42.5400000000
# 39.5800000000
# 37.9200000000
# 37.6200000000
# 38.4200000000
# 46.4200000000
# 48.9200000000
# 43.1200000000
# 40.0400000000
# 39.1200000000
# 40.8300000000
# 41.4200000000
# 40.5800000000
# 36.4600000000
# 34.6200000000
# 32.1700000000
# 35.1200000000
# 34.0400000000
# 32.3800000000
# 40.4600000000
# 40.6200000000
# 43.1700000000
# 36.1700000000
# 38.3800000000
# 39.5400000000
# 36.1700000000
# 36.9600000000
# 36.3300000000
# 39.3300000000
# 40.8800000000
# 44.7900000000
# 43.7900000000
# 46.1700000000
# 48.2100000000
# 43.8800000000
# 44.3800000000
# 41.7500000000
# 39.6200000000
# 42.7900000000
# 47.2900000000
# 48.3300000000
# 47.3300000000
# 48.0800000000
# 45.1700000000
# 43.8800000000
# 46.0000000000
# 46.9200000000
# 45.4600000000
# 44.8300000000
# 44.3800000000
# 46.3300000000
# 44.2100000000
# 43.7500000000
# 45.2100000000
# 47.5400000000
# 47.7900000000
# 47.8800000000
# 48.6700000000
# 46.9600000000
# 47.9200000000
# 46.0000000000
# 51.7500000000
# 50.1200000000
# 50.0000000000
# 49.5800000000
# 48.3300000000
# 52.0800000000
# 53.7900000000
# 52.2900000000
# 51.1700000000
# 51.1200000000
# 53.0800000000
# 51.5000000000
# 50.8300000000
# 52.3800000000
# 49.6700000000
# 49.1200000000
# 47.2500000000
# 46.1200000000
# 46.5000000000
# 47.6700000000
# 48.5400000000
# 53.2900000000
# 53.9600000000
# 56.2500000000
# 48.8300000000
# 49.0000000000
# 51.6200000000
# 53.9600000000
# 56.0000000000
# 54.3800000000
# 50.4600000000
# 48.5000000000
# 49.9200000000
# 48.9600000000
# 46.4200000000
# 52.5800000000
# 55.0400000000
# 54.7100000000
# 57.4600000000
# 59.5400000000
# 61.4600000000
# 59.7100000000
# 55.0800000000
# 55.6200000000
# 59.9200000000
# 62.6200000000
# 64.2500000000
# 63.9600000000
# 56.6700000000
# 55.0800000000
# 57.9600000000
# 59.5000000000
# 59.0400000000
# 56.9600000000
# 57.0000000000
# 63.1200000000
# 65.6700000000
# 60.1200000000
# 54.0000000000
# 55.2900000000
# 57.9200000000
# 60.0000000000
# 57.0000000000
# 57.0400000000
# 56.6200000000
# 58.5000000000
# 57.5800000000
# 55.9600000000
# 58.4200000000
# 61.5800000000
# 59.7500000000
# 59.6200000000
# 62.4600000000
# 64.8800000000
# 67.0400000000
# 66.2500000000
# 61.0400000000
# 61.0000000000
# 64.2100000000
# 65.4200000000
# 62.8800000000
# 64.4200000000
# 63.7500000000
# 63.0000000000
# 65.4600000000
# 68.1700000000
# 66.6700000000
# 63.8300000000
# 66.0800000000
# 65.0400000000
# 60.7500000000
# 63.8300000000
# 66.2500000000
# 62.4600000000
# 65.8300000000
# 64.7900000000
# 63.7500000000
# 64.8800000000
# 66.5800000000
# 66.1200000000
# 63.5400000000
# 64.2100000000
# 66.5000000000
# 64.6200000000
# 66.4200000000
# 65.9200000000
# 63.9600000000
# 62.1200000000
# 64.7100000000
# 67.4200000000
# 66.5000000000
# 68.9200000000
# 70.2900000000
# 71.0800000000
# 69.3800000000
# 66.4200000000
# 64.9600000000
# 66.3300000000
# 67.2500000000
# 68.0800000000
# 68.5000000000
# 67.4600000000
# 64.5800000000
# 64.5400000000
# 62.2500000000
# 61.8300000000
# 63.3300000000
# 65.2500000000
# 64.0400000000
# 64.1700000000
# 62.7100000000
# 64.1700000000
# 67.7100000000
# 67.7500000000
# 64.3300000000
# 61.0000000000
# 62.8300000000
# 67.9200000000
# 70.8800000000
# 70.6200000000
# 67.2900000000
# 65.1700000000
# 64.2900000000
# 68.0800000000
# 71.0000000000
# 72.1200000000
# 72.2500000000
# 69.5800000000
# 66.9600000000
# 64.2900000000
# 60.4600000000
# 57.8300000000
# 60.7900000000
# 64.4200000000
# 60.6200000000
# 61.5400000000
# 58.6200000000
# 59.8800000000
# 58.4200000000
# 54.0400000000
# 53.3300000000
# 52.5800000000
# 55.2500000000
# 56.7100000000
# 58.4200000000
# 56.0000000000
# 59.0800000000
# 59.2500000000
# 59.1700000000
# 61.2900000000
# 62.4600000000
# 55.1700000000
# 53.3300000000
# 52.8800000000
# 55.2500000000
# 51.8800000000
# 50.8800000000
# 51.7100000000
# 52.7900000000
# 50.6200000000
# 48.2900000000
# 49.3300000000
# 47.6700000000
# 46.5400000000
# 46.4200000000
# 44.9200000000
# 50.1700000000
# 52.6200000000
# 53.8800000000
# 49.7900000000
# 53.2100000000
# 48.9600000000
# 47.2100000000
# 52.1700000000
# 50.8300000000
# 51.2500000000
# 50.0000000000
# 50.5400000000
# 49.8800000000
# 59.0000000000
# 38
# 38
# 38
# 39
# 42
# 47
# 46
# 45
# 44
# 43
# 44
# 44
# 43
# 43
# 43
# 47
# 46
# 49
# 47
# 46
# 44
# 44
# 47
# 48
# 50
# 49
# 51
# 47
# 46
# 46
# 46
# 45
# 45
# 45
# 45
# 48
# 51
# 50
# 50
# 50
# 48
# 48
# 48
# 49
# 49
# 50
# 49
# 49
# 48
# 48
# 47
# 48
# 48
# 46
# 46
# 46
# 46
# 49
# 48
# 48
# 47
# 47
# 48
# 51
# 55
# 56
# 56
# 54
# 56
# 53
# 54
# 57
# 57
# 50
# 50
# 50
# 50
# 50
# 50
# 49
# 48
# 49
# 48
# 48
# 57
# 57
# 55
# 50
# 55
# 54
# 50
# 49
# 48
# 47
# 51
# 51
# 55
# 55
# 56
# 54
# 48
# 45
# 44
# 50
# 50
# 54
# 58
# 59
# 62
# 62
# 60
# 53
# 51
# 47
# 51
# 51
# 55
# 55
# 52
# 51
# 54
# 54
# 56
# 55
# 54
# 56
# 58
# 61
# 61
# 62
# 59
# 60
# 59
# 59
# 60
# 60
# 60
# 64
# 65
# 65
# 68
# 67
# 63
# 61
# 62
# 65
# 69
# 48
# 42
# 44
# 46
# 45
# 44
# 47
# 50
# 50
# 46
# 49
# 53
# 49
# 43
# 42
# 45
# 49
# 51
# 43
# 46
# 51
# 60
# 50
# 48
# 51
# 52
# 51
# 45
# 45
# 53
# 49
# 53
# 58
# 53
# 54
# 52
# 54
# 48
# 50
# 52
# 53
# 55
# 55
# 53
# 53
# 48
# 49
# 50
# 48
# 51
# 57
# 56
# 58
# 59
# 63
# 63
# 56
# 59
# 54
# 51
# 51
# 52
# 54
# 48
# 47
# 45
# 48
# 53
# 52
# 51
# 56
# 55
# 55
# 54
# 56
# 55
# 59
# 57
# 57
# 56
# 57
# 59
# 58
# 57
# 56
# 53
# 57
# 58
# 56
# 56
# 57
# 57
# 58
# 55
# 55
# 56
# 58
# 59
# 64
# 64
# 56
# 60
# 59
# 57
# 61
# 59
# 58
# 62
# 62
# 61
# 57
# 55
# 58
# 58
# 56
# 58
# 55
# 56
# 56
# 59
# 60
# 58
# 62
# 64
# 62
# 58
# 60
# 60
# 63
# 66
# 61
# 59
# 55
# 52
# 57
# 59
# 59
# 63
# 58
# 55
# 57
# 59
# 55
# 54
# 54
# 49
# 53
# 54
# 56
# 54
# 48
# 57
# 54
# 49
# 47
# 48
# 51
# 55
# 54
# 52
# 54
# 51
# 50
# 50
# 52
# 50
# 54
# 51
# 54
# 48
# 46
# 41
# 48
# 50
# 46
# 50
# 48
# 47
# 50
# 48
# 46
# 41
# 39
# 37
# 49
# 50
# 49
# 49
# 47
# 46
# 46
# 46
# 43
# 46
# 48
# 50
# 50
# 47
# 50
# 49
# 46
# 43
# 46
# 46
# 48
# 44
# 40
# 48
# 47
# 51
# 47
# 49
# 41
# 47
# 49
# 45
# 43
# 42
# 38
# 40
# 36
# 31
# 37
# 46
# 39
# 36
# 38
# 36
# 36
# 37
# 36
# 36
# 38
# 30
# 31
# 34
# 33
# 30
# 25
# 16
# 12
# 18
# 28
# 33
# 28
# 20
# 20
# 19
# 20
# 8
# 11
# 30
# 35
# 37
# 33
# 34
# 29
# 29
# 26
# 26
# 34
# 27
# 31
# 30
# 32
# 25
# 16
# 16
# 15
# 17
# 14
# 29
# 32
# 30
# 24
# 17
# 20
# 22
# 27
# 32
# 35
# 39
# 38
# 34

# %%
city = "Vancouver"
for row in session.query(getattr(Avg_temp, city), Avg_temp.datetime).filter(Avg_temp.datetime.like('%2015-05-%')):
    print(row)
# Out:
# (Decimal('50.9200000000'), datetime.datetime(2015, 5, 1, 0, 0))
# (Decimal('51.0000000000'), datetime.datetime(2015, 5, 2, 0, 0))
# (Decimal('52.1700000000'), datetime.datetime(2015, 5, 3, 0, 0))
# (Decimal('52.8300000000'), datetime.datetime(2015, 5, 4, 0, 0))
# (Decimal('49.6700000000'), datetime.datetime(2015, 5, 5, 0, 0))
# (Decimal('50.8800000000'), datetime.datetime(2015, 5, 6, 0, 0))
# (Decimal('53.7100000000'), datetime.datetime(2015, 5, 7, 0, 0))
# (Decimal('56.0800000000'), datetime.datetime(2015, 5, 8, 0, 0))
# (Decimal('57.4600000000'), datetime.datetime(2015, 5, 9, 0, 0))
# (Decimal('57.4200000000'), datetime.datetime(2015, 5, 10, 0, 0))
# (Decimal('56.7100000000'), datetime.datetime(2015, 5, 11, 0, 0))
# (Decimal('56.7100000000'), datetime.datetime(2015, 5, 12, 0, 0))
# (Decimal('56.7500000000'), datetime.datetime(2015, 5, 13, 0, 0))
# (Decimal('54.4600000000'), datetime.datetime(2015, 5, 14, 0, 0))
# (Decimal('58.0800000000'), datetime.datetime(2015, 5, 15, 0, 0))
# (Decimal('57.4600000000'), datetime.datetime(2015, 5, 16, 0, 0))
# (Decimal('57.2900000000'), datetime.datetime(2015, 5, 17, 0, 0))
# (Decimal('59.2100000000'), datetime.datetime(2015, 5, 18, 0, 0))
# (Decimal('61.6700000000'), datetime.datetime(2015, 5, 19, 0, 0))
# (Decimal('61.7900000000'), datetime.datetime(2015, 5, 20, 0, 0))
# (Decimal('63.0400000000'), datetime.datetime(2015, 5, 21, 0, 0))
# (Decimal('62.2100000000'), datetime.datetime(2015, 5, 22, 0, 0))
# (Decimal('60.6700000000'), datetime.datetime(2015, 5, 23, 0, 0))
# (Decimal('59.0400000000'), datetime.datetime(2015, 5, 24, 0, 0))
# (Decimal('56.9200000000'), datetime.datetime(2015, 5, 25, 0, 0))
# (Decimal('56.7100000000'), datetime.datetime(2015, 5, 26, 0, 0))
# (Decimal('60.1700000000'), datetime.datetime(2015, 5, 27, 0, 0))
# (Decimal('62.5400000000'), datetime.datetime(2015, 5, 28, 0, 0))
# (Decimal('64.0800000000'), datetime.datetime(2015, 5, 29, 0, 0))
# (Decimal('61.7100000000'), datetime.datetime(2015, 5, 30, 0, 0))
# (Decimal('59.9600000000'), datetime.datetime(2015, 5, 31, 0, 0))
# C:\users\t0nb3\Anaconda3\lib\site-packages\pymysql\cursors.py:165: Warning: (1292, "Incorrect datetime value: '%2015-05-%' for column 'datetime' at row 1")
#   result = self._query(query)

# %%
#Humidity = Base.classes.humidity
City_attributes = Base.classes.city_attributes

# %%
first_row = session.query(Daily_avg_temps).first()
first_row.__dict__
# Out:
# {'Albuquerque': Decimal('15.4300000000'),
#  'Atlanta': Decimal('37.3000000000'),
#  'Boston': Decimal('25.9600000000'),
#  'Charlotte': Decimal('33.1700000000'),
#  'Chicago': Decimal('22.8300000000'),
#  'Dallas': Decimal('34.0900000000'),
#  'Denver': Decimal('6.6100000000'),
#  'Detroit': Decimal('20.1700000000'),
#  'Houston': Decimal('43.0400000000'),
#  'Indianapolis': Decimal('21.0000000000'),
#  'Jacksonville': Decimal('56.4300000000'),
#  'Kansas City': Decimal('20.7000000000'),
#  'Las Vegas': Decimal('30.9100000000'),
#  'Los Angeles': Decimal('34.3900000000'),
#  'Miami': Decimal('74.7400000000'),
#  'Minneapolis': Decimal('15.0000000000'),
#  'Montreal': Decimal('19.4800000000'),
#  'Nashville': Decimal('26.3000000000'),
#  'New York': Decimal('24.5200000000'),
#  'Philadelphia': Decimal('25.4800000000'),
#  'Phoenix': Decimal('31.5200000000'),
#  'Pittsburgh': Decimal('24.8700000000'),
#  'Portland': Decimal('22.1700000000'),
#  'Saint Louis': Decimal('23.2600000000'),
#  'San Antonio': Decimal('38.7000000000'),
#  'San Diego': Decimal('31.9600000000'),
#  'San Francisco': Decimal('47.1300000000'),
#  'Seattle': Decimal('28.0900000000'),
#  'Toronto': Decimal('23.3500000000'),
#  'Vancouver': Decimal('32.9600000000'),
#  '_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1767eaed668>,
#  'datetime': datetime.datetime(2015, 1, 1, 0, 0),
#  'id': 1}

# %%
first_row = session.query(Humidity).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x275bfeefda0>,
#  'alb': '50',
#  'atl': '94',
#  'bee': '50',
#  'bos': '68',
#  'char': '87',
#  'chi': '71',
#  'dal': '87',
#  'date_id': 1,
#  'datetime': datetime.datetime(2012, 10, 1, 13, 0),
#  'den': '62',
#  'det': '76',
#  'eil': '22',
#  'hai': '51',
#  'hou': '93',
#  'ind': '76',
#  'jac': '88',
#  'jer': '50',
#  'ksc': '71',
#  'la': '88',
#  'laveg': '22',
#  'mai': '83',
#  'min': '67',
#  'mon': '93',
#  'nah': '51',
#  'nash': '100',
#  'nyc': '58',
#  'phi': '71',
#  'pho': '23',
#  'pit': '93',
#  'por': '81',
#  'sand': '82',
#  'sant': '93',
#  'sea': '81',
#  'sfran': '88',
#  'stlo': '71',
#  'tel': '63',
#  'tor': '82',
#  'van': '76'}

# %%
first_row = session.query(City_attributes).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x2943c85c1d0>,
#  'abbr': 'van',
#  'city': 'Vancouver',
#  'city_id': 1,
#  'country': 'Canada',
#  'latitude': Decimal('49.2496600000'),
#  'longitude': Decimal('-123.1193390000')}

# %%
city_list = []
for row in session.query(City_attributes.city, City_attributes.country, City_attributes.abbr, City_attributes.latitude, City_attributes.longitude).all():
    city_list.append({
        "city_name": row[0],
        "country": row[1],
        "city_abbr": row[2],
        "lat": row[3],
        "lon": row[4]
    })
    print(row)
# Out:
# ('Vancouver', 'Canada', 'van', Decimal('49.2496600000'), Decimal('-123.1193390000'))
# ('Portland', 'United States', 'por', Decimal('45.5234490000'), Decimal('-122.6762080000'))
# ('San Francisco', 'United States', 'sfran', Decimal('37.7749290000'), Decimal('-122.4194180000'))
# ('Seattle', 'United States', 'sea', Decimal('47.6062090000'), Decimal('-122.3320690000'))
# ('Los Angeles', 'United States', 'la', Decimal('34.0522310000'), Decimal('-118.2436830000'))
# ('San Diego', 'United States', 'sand', Decimal('32.7153280000'), Decimal('-117.1572570000'))
# ('Las Vegas', 'United States', 'laveg', Decimal('36.1749690000'), Decimal('-115.1372220000'))
# ('Phoenix', 'United States', 'pho', Decimal('33.4483800000'), Decimal('-112.0740430000'))
# ('Albuquerque', 'United States', 'alb', Decimal('35.0844920000'), Decimal('-106.6511380000'))
# ('Denver', 'United States', 'den', Decimal('39.7391510000'), Decimal('-104.9847030000'))
# ('SanAntonio', 'United States', 'sant', Decimal('29.4241200000'), Decimal('-98.4936290000'))
# ('Dallas', 'United States', 'dal', Decimal('32.7830580000'), Decimal('-96.8066710000'))
# ('Houston', 'United States', 'hou', Decimal('29.7632810000'), Decimal('-95.3632740000'))
# ('Kansas City', 'United States', 'ksc', Decimal('39.0997310000'), Decimal('-94.5785680000'))
# ('Minneapolis', 'United States', 'min', Decimal('44.9799690000'), Decimal('-93.2638400000'))
# ('Saint Louis', 'United States', 'stlo', Decimal('38.6272700000'), Decimal('-90.1978910000'))
# ('Chicago', 'United States', 'chi', Decimal('41.8500290000'), Decimal('-87.6500470000'))
# ('Nashville', 'United States', 'nash', Decimal('36.1658900000'), Decimal('-86.7844390000'))
# ('Indianapolis', 'United States', 'ind', Decimal('39.7683790000'), Decimal('-86.1580430000'))
# ('Atlanta', 'United States', 'atl', Decimal('33.7490010000'), Decimal('-84.3879780000'))
# ('Detroit', 'United States', 'det', Decimal('42.3314290000'), Decimal('-83.0457530000'))
# ('Jacksonville', 'United States', 'jac', Decimal('30.3321800000'), Decimal('-81.6556470000'))
# ('Charlotte', 'United States', 'char', Decimal('35.2270890000'), Decimal('-80.8431320000'))
# ('Miami', 'United States', 'mai', Decimal('25.7742690000'), Decimal('-80.1936570000'))
# ('Pittsburgh', 'United States', 'pit', Decimal('40.4406200000'), Decimal('-79.9958880000'))
# ('Toronto', 'Canada', 'tor', Decimal('43.7001110000'), Decimal('-79.4162980000'))
# ('Philadelphia', 'United States', 'phi', Decimal('39.9523390000'), Decimal('-75.1637880000'))
# ('New York', 'United States', 'nyc', Decimal('40.7142720000'), Decimal('-74.0059660000'))
# ('Montreal', 'Canada', 'mon', Decimal('45.5088390000'), Decimal('-73.5878070000'))
# ('Boston', 'United States', 'bos', Decimal('42.3584290000'), Decimal('-71.0597690000'))
# ('Beersheba', 'Israel', 'bee', Decimal('31.2518100000'), Decimal('34.7913020000'))
# ('Tel Aviv', 'Israel', 'tel', Decimal('32.0833280000'), Decimal('34.7999990000'))
# ('Eilat', 'Israel', 'eil', Decimal('29.5580500000'), Decimal('34.9482120000'))
# ('Haifa', 'Israel', 'hai', Decimal('32.8155590000'), Decimal('34.9891700000'))
# ('Nahariyya', 'Israel', 'nah', Decimal('33.0058590000'), Decimal('35.0940900000'))
# ('Jerusalem', 'Israel', 'jer', Decimal('31.7690390000'), Decimal('35.2163310000'))

# %%
city_list
for city in city_list:
    print("(", city['lat'], ",", city['lon'], ")")
for city in city_list:
    print("city:", city['city_name'], "country:", city['country'])
# Out:
# ( 49.2496600000 , -123.1193390000 )
# ( 45.5234490000 , -122.6762080000 )
# ( 37.7749290000 , -122.4194180000 )
# ( 47.6062090000 , -122.3320690000 )
# ( 34.0522310000 , -118.2436830000 )
# ( 32.7153280000 , -117.1572570000 )
# ( 36.1749690000 , -115.1372220000 )
# ( 33.4483800000 , -112.0740430000 )
# ( 35.0844920000 , -106.6511380000 )
# ( 39.7391510000 , -104.9847030000 )
# ( 29.4241200000 , -98.4936290000 )
# ( 32.7830580000 , -96.8066710000 )
# ( 29.7632810000 , -95.3632740000 )
# ( 39.0997310000 , -94.5785680000 )
# ( 44.9799690000 , -93.2638400000 )
# ( 38.6272700000 , -90.1978910000 )
# ( 41.8500290000 , -87.6500470000 )
# ( 36.1658900000 , -86.7844390000 )
# ( 39.7683790000 , -86.1580430000 )
# ( 33.7490010000 , -84.3879780000 )
# ( 42.3314290000 , -83.0457530000 )
# ( 30.3321800000 , -81.6556470000 )
# ( 35.2270890000 , -80.8431320000 )
# ( 25.7742690000 , -80.1936570000 )
# ( 40.4406200000 , -79.9958880000 )
# ( 43.7001110000 , -79.4162980000 )
# ( 39.9523390000 , -75.1637880000 )
# ( 40.7142720000 , -74.0059660000 )
# ( 45.5088390000 , -73.5878070000 )
# ( 42.3584290000 , -71.0597690000 )
# ( 31.2518100000 , 34.7913020000 )
# ( 32.0833280000 , 34.7999990000 )
# ( 29.5580500000 , 34.9482120000 )
# ( 32.8155590000 , 34.9891700000 )
# ( 33.0058590000 , 35.0940900000 )
# ( 31.7690390000 , 35.2163310000 )
# city: Vancouver country: Canada
# city: Portland country: United States
# city: San Francisco country: United States
# city: Seattle country: United States
# city: Los Angeles country: United States
# city: San Diego country: United States
# city: Las Vegas country: United States
# city: Phoenix country: United States
# city: Albuquerque country: United States
# city: Denver country: United States
# city: SanAntonio country: United States
# city: Dallas country: United States
# city: Houston country: United States
# city: Kansas City country: United States
# city: Minneapolis country: United States
# city: Saint Louis country: United States
# city: Chicago country: United States
# city: Nashville country: United States
# city: Indianapolis country: United States
# city: Atlanta country: United States
# city: Detroit country: United States
# city: Jacksonville country: United States
# city: Charlotte country: United States
# city: Miami country: United States
# city: Pittsburgh country: United States
# city: Toronto country: Canada
# city: Philadelphia country: United States
# city: New York country: United States
# city: Montreal country: Canada
# city: Boston country: United States
# city: Beersheba country: Israel
# city: Tel Aviv country: Israel
# city: Eilat country: Israel
# city: Haifa country: Israel
# city: Nahariyya country: Israel
# city: Jerusalem country: Israel

# %%
from citytest import citydata

# %%
citydata()
# Out:
# [{'city_abbr': 'van',
#   'city_name': 'Vancouver',
#   'country': 'Canada',
#   'lat': Decimal('49.2496600000'),
#   'lon': Decimal('-123.1193390000')},
#  {'city_abbr': 'por',
#   'city_name': 'Portland',
#   'country': 'United States',
#   'lat': Decimal('45.5234490000'),
#   'lon': Decimal('-122.6762080000')},
#  {'city_abbr': 'sfran',
#   'city_name': 'San Francisco',
#   'country': 'United States',
#   'lat': Decimal('37.7749290000'),
#   'lon': Decimal('-122.4194180000')},
#  {'city_abbr': 'sea',
#   'city_name': 'Seattle',
#   'country': 'United States',
#   'lat': Decimal('47.6062090000'),
#   'lon': Decimal('-122.3320690000')},
#  {'city_abbr': 'la',
#   'city_name': 'Los Angeles',
#   'country': 'United States',
#   'lat': Decimal('34.0522310000'),
#   'lon': Decimal('-118.2436830000')},
#  {'city_abbr': 'sand',
#   'city_name': 'San Diego',
#   'country': 'United States',
#   'lat': Decimal('32.7153280000'),
#   'lon': Decimal('-117.1572570000')},
#  {'city_abbr': 'laveg',
#   'city_name': 'Las Vegas',
#   'country': 'United States',
#   'lat': Decimal('36.1749690000'),
#   'lon': Decimal('-115.1372220000')},
#  {'city_abbr': 'pho',
#   'city_name': 'Phoenix',
#   'country': 'United States',
#   'lat': Decimal('33.4483800000'),
#   'lon': Decimal('-112.0740430000')},
#  {'city_abbr': 'alb',
#   'city_name': 'Albuquerque',
#   'country': 'United States',
#   'lat': Decimal('35.0844920000'),
#   'lon': Decimal('-106.6511380000')},
#  {'city_abbr': 'den',
#   'city_name': 'Denver',
#   'country': 'United States',
#   'lat': Decimal('39.7391510000'),
#   'lon': Decimal('-104.9847030000')},
#  {'city_abbr': 'sant',
#   'city_name': 'SanAntonio',
#   'country': 'United States',
#   'lat': Decimal('29.4241200000'),
#   'lon': Decimal('-98.4936290000')},
#  {'city_abbr': 'dal',
#   'city_name': 'Dallas',
#   'country': 'United States',
#   'lat': Decimal('32.7830580000'),
#   'lon': Decimal('-96.8066710000')},
#  {'city_abbr': 'hou',
#   'city_name': 'Houston',
#   'country': 'United States',
#   'lat': Decimal('29.7632810000'),
#   'lon': Decimal('-95.3632740000')},
#  {'city_abbr': 'ksc',
#   'city_name': 'Kansas City',
#   'country': 'United States',
#   'lat': Decimal('39.0997310000'),
#   'lon': Decimal('-94.5785680000')},
#  {'city_abbr': 'min',
#   'city_name': 'Minneapolis',
#   'country': 'United States',
#   'lat': Decimal('44.9799690000'),
#   'lon': Decimal('-93.2638400000')},
#  {'city_abbr': 'stlo',
#   'city_name': 'Saint Louis',
#   'country': 'United States',
#   'lat': Decimal('38.6272700000'),
#   'lon': Decimal('-90.1978910000')},
#  {'city_abbr': 'chi',
#   'city_name': 'Chicago',
#   'country': 'United States',
#   'lat': Decimal('41.8500290000'),
#   'lon': Decimal('-87.6500470000')},
#  {'city_abbr': 'nash',
#   'city_name': 'Nashville',
#   'country': 'United States',
#   'lat': Decimal('36.1658900000'),
#   'lon': Decimal('-86.7844390000')},
#  {'city_abbr': 'ind',
#   'city_name': 'Indianapolis',
#   'country': 'United States',
#   'lat': Decimal('39.7683790000'),
#   'lon': Decimal('-86.1580430000')},
#  {'city_abbr': 'atl',
#   'city_name': 'Atlanta',
#   'country': 'United States',
#   'lat': Decimal('33.7490010000'),
#   'lon': Decimal('-84.3879780000')},
#  {'city_abbr': 'det',
#   'city_name': 'Detroit',
#   'country': 'United States',
#   'lat': Decimal('42.3314290000'),
#   'lon': Decimal('-83.0457530000')},
#  {'city_abbr': 'jac',
#   'city_name': 'Jacksonville',
#   'country': 'United States',
#   'lat': Decimal('30.3321800000'),
#   'lon': Decimal('-81.6556470000')},
#  {'city_abbr': 'char',
#   'city_name': 'Charlotte',
#   'country': 'United States',
#   'lat': Decimal('35.2270890000'),
#   'lon': Decimal('-80.8431320000')},
#  {'city_abbr': 'mai',
#   'city_name': 'Miami',
#   'country': 'United States',
#   'lat': Decimal('25.7742690000'),
#   'lon': Decimal('-80.1936570000')},
#  {'city_abbr': 'pit',
#   'city_name': 'Pittsburgh',
#   'country': 'United States',
#   'lat': Decimal('40.4406200000'),
#   'lon': Decimal('-79.9958880000')},
#  {'city_abbr': 'tor',
#   'city_name': 'Toronto',
#   'country': 'Canada',
#   'lat': Decimal('43.7001110000'),
#   'lon': Decimal('-79.4162980000')},
#  {'city_abbr': 'phi',
#   'city_name': 'Philadelphia',
#   'country': 'United States',
#   'lat': Decimal('39.9523390000'),
#   'lon': Decimal('-75.1637880000')},
#  {'city_abbr': 'nyc',
#   'city_name': 'New York',
#   'country': 'United States',
#   'lat': Decimal('40.7142720000'),
#   'lon': Decimal('-74.0059660000')},
#  {'city_abbr': 'mon',
#   'city_name': 'Montreal',
#   'country': 'Canada',
#   'lat': Decimal('45.5088390000'),
#   'lon': Decimal('-73.5878070000')},
#  {'city_abbr': 'bos',
#   'city_name': 'Boston',
#   'country': 'United States',
#   'lat': Decimal('42.3584290000'),
#   'lon': Decimal('-71.0597690000')},
#  {'city_abbr': 'bee',
#   'city_name': 'Beersheba',
#   'country': 'Israel',
#   'lat': Decimal('31.2518100000'),
#   'lon': Decimal('34.7913020000')},
#  {'city_abbr': 'tel',
#   'city_name': 'Tel Aviv',
#   'country': 'Israel',
#   'lat': Decimal('32.0833280000'),
#   'lon': Decimal('34.7999990000')},
#  {'city_abbr': 'eil',
#   'city_name': 'Eilat',
#   'country': 'Israel',
#   'lat': Decimal('29.5580500000'),
#   'lon': Decimal('34.9482120000')},
#  {'city_abbr': 'hai',
#   'city_name': 'Haifa',
#   'country': 'Israel',
#   'lat': Decimal('32.8155590000'),
#   'lon': Decimal('34.9891700000')},
#  {'city_abbr': 'nah',
#   'city_name': 'Nahariyya',
#   'country': 'Israel',
#   'lat': Decimal('33.0058590000'),
#   'lon': Decimal('35.0940900000')},
#  {'city_abbr': 'jer',
#   'city_name': 'Jerusalem',
#   'country': 'Israel',
#   'lat': Decimal('31.7690390000'),
#   'lon': Decimal('35.2163310000')}]

# %%
for row in session.query(City_attributes.city).all():
    print(row[0])
# Out:
# Vancouver
# Portland
# San Francisco
# Seattle
# Los Angeles
# San Diego
# Las Vegas
# Phoenix
# Albuquerque
# Denver
# SanAntonio
# Dallas
# Houston
# Kansas City
# Minneapolis
# Saint Louis
# Chicago
# Nashville
# Indianapolis
# Atlanta
# Detroit
# Jacksonville
# Charlotte
# Miami
# Pittsburgh
# Toronto
# Philadelphia
# New York
# Montreal
# Boston
# Beersheba
# Tel Aviv
# Eilat
# Haifa
# Nahariyya
# Jerusalem

# %%
session.close()

# %%
from sqls import city_data

# %%
cities = city_data()

# %%
city_list = []
for city in cities:
    if (city['country'] == 'United States'):
        city_list.append(city['city_name'])

# %%
city_list
# Out:
# ['Portland',
#  'San Francisco',
#  'Seattle',
#  'Los Angeles',
#  'San Diego',
#  'Las Vegas',
#  'Phoenix',
#  'Albuquerque',
#  'Denver',
#  'SanAntonio',
#  'Dallas',
#  'Houston',
#  'Kansas City',
#  'Minneapolis',
#  'Saint Louis',
#  'Chicago',
#  'Nashville',
#  'Indianapolis',
#  'Atlanta',
#  'Detroit',
#  'Jacksonville',
#  'Charlotte',
#  'Miami',
#  'Pittsburgh',
#  'Philadelphia',
#  'New York',
#  'Boston']
